# %%
import synapseclient


syn = synapseclient.login(email="soon2soon@gmail.com", password="infos#123", rememberMe=True)

import pandas as pd
import json
import numpy as np

currentDownloaded = 0


# syn10701954 for test


while currentDownloaded < 20000:
    query_ldopa_table = syn.tableQuery("SELECT 'dataFileHandleId' FROM syn10701954 LIMIT " + str(currentDownloaded + 200))

    tsv_files = syn.downloadTableColumns(query_ldopa_table, "dataFileHandleId")
   
    
    currentDownloaded = currentDownloaded + 200
    print(str(currentDownloaded) + " done so far.")

print("download done.")
# Out:
# Welcome, Seongsoon Kim!
#
# ...
# 200 done so far.
# ...
# 400 done so far.
# ...
# 600 done so far.
# ...
# 800 done so far.
# ...
# 1000 done so far.
# ...
# 1200 done so far.
# ...
# 1400 done so far.
# ...
# 1600 done so far.
# ...
# 1800 done so far.
# ...
# 2000 done so far.
# ...
# 2200 done so far.
# ...
# 2400 done so far.
# ...
# 2600 done so far.
# ...
# 2800 done so far.
# ...
# 3000 done so far.
# ...
# 3200 done so far.
# ...
# 3400 done so far.
# ...
# 3600 done so far.
# ...
# 3800 done so far.
# ...
# 4000 done so far.
# ...
# 4200 done so far.
# ...
# 4400 done so far.
# ...
# 4600 done so far.
# ...
# 4800 done so far.
# ...
# 5000 done so far.
# ...
# 5200 done so far.
# ...
# 5400 done so far.
# ...
# 5600 done so far.
# ...
# 5800 done so far.
# ...
# 6000 done so far.
# ...
# 6200 done so far.
# ...
# 6400 done so far.
# ...
# 6600 done so far.
# ...
# 6800 done so far.
# ...
# 7000 done so far.
# ...
# 7200 done so far.
# ...
# 7400 done so far.
# ...
# 7600 done so far.
# ...
# 7800 done so far.
# ...
# 8000 done so far.
# ...
# 8200 done so far.
# ...
# 8400 done so far.
# ...
# 8600 done so far.
# ...
# 8800 done so far.
# ...
# 9000 done so far.
# ...
# 9200 done so far.
# ...
# 9400 done so far.
# ...
# 9600 done so far.
# ...
