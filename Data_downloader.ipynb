# %%
import synapseclient


syn = synapseclient.login(email="soon2soon@gmail.com", password="infos#123", rememberMe=True)

import pandas as pd
import json
import numpy as np

currentDownloaded = 0


# request data to server 200 files for a time. The server does not response if I try to download all data at once.



while currentDownloaded < 40000:
    # read in the healthCodes of interest from demographics training table
    demo_syntable = syn.tableQuery("SELECT * FROM syn10733842")
    demo = demo_syntable.asDataFrame()
    healthCodeList = ", ".join( repr(i) for i in demo["healthCode"]) 

    # Query 'walking training table' for walk data recordIDs and healthCodes. 
    INPUT_WALKING_ACTIVITY_TABLE_SYNID = "syn10733842"
    actv_walking_syntable = syn.tableQuery(('SELECT "recordId", "healthCode", "deviceMotion_walking_outbound.json.items" FROM {0} WHERE healthCode IN ({1}) AND "deviceMotion_walking_outbound.json.items" is not null LIMIT ' + str(currentDownloaded + 200)).format(INPUT_WALKING_ACTIVITY_TABLE_SYNID, healthCodeList))
    
    actv_walking = actv_walking_syntable.asDataFrame()
    actv_walking['idx'] = actv_walking.index




    ######################
    # Download JSON Files
    ######################
    # bulk download walk JSON files containing sensor data
    walk_json_files = syn.downloadTableColumns(actv_walking_syntable, "deviceMotion_walking_outbound.json.items")
    items = walk_json_files.items()

    currentDownloaded = currentDownloaded + 200
                                           
    print(str(currentDownloaded) + " done.")



# # create pandas dataframe of JSON filepaths and filehandleIDs
# walk_json_files_temp = pd.DataFrame({"deviceMotion_walking_return.json.items": [i[0] for i in items], "outbound_walk_json_file": [i[1] for i in items]})

# # convert ints to strings for merging
# actv_walking["deviceMotion_walking_return.json.items"] = actv_walking["deviceMotion_walking_return.json.items"].astype(str)

# # merge IDs/healthCodes with JSON data
# actv_walk_temp = pd.merge(actv_walking, walk_json_files_temp, on="deviceMotion_walking_return.json.items")


# print("merge done.")
# Out:
# Welcome, Seongsoon Kim!
#
# Downloading 0 files, 200 cached locally
# 200 done.
# Downloading 0 files, 400 cached locally
# 400 done.
# Downloading 0 files, 600 cached locally
# 600 done.
# Downloading 0 files, 800 cached locally
# 800 done.
# Downloading 0 files, 1000 cached locally
# 1000 done.
# Downloading 0 files, 1200 cached locally
# 1200 done.
# Downloading 0 files, 1400 cached locally
# 1400 done.
# Downloading 0 files, 1600 cached locally
# 1600 done.
# Downloading 0 files, 1800 cached locally
# 1800 done.
# Downloading 0 files, 2000 cached locally
# 2000 done.
# Downloading 0 files, 2200 cached locally
# 2200 done.
# Downloading 0 files, 2400 cached locally
# 2400 done.
# Downloading 0 files, 2600 cached locally
# 2600 done.
# Downloading 0 files, 2800 cached locally
# 2800 done.
# Downloading 0 files, 3000 cached locally
# 3000 done.
# Downloading 0 files, 3200 cached locally
# 3200 done.
# Downloading 0 files, 3400 cached locally
# 3400 done.
# Downloading 0 files, 3600 cached locally
# 3600 done.
# Downloading 0 files, 3800 cached locally
# 3800 done.
# Downloading 0 files, 4000 cached locally
# 4000 done.
# Downloading 0 files, 4200 cached locally
# 4200 done.
# Downloading 0 files, 4400 cached locally
# 4400 done.
# Downloading 0 files, 4600 cached locally
# 4600 done.
# Downloading 0 files, 4800 cached locally
# 4800 done.
# Downloading 0 files, 5000 cached locally
# 5000 done.
# Downloading 0 files, 5200 cached locally
# 5200 done.
# Downloading 0 files, 5400 cached locally
# 5400 done.
# Downloading 0 files, 5600 cached locally
# 5600 done.
# Downloading 0 files, 5800 cached locally
# 5800 done.
# Downloading 0 files, 6000 cached locally
# 6000 done.
# Downloading 0 files, 6200 cached locally
# 6200 done.
# Downloading 0 files, 6400 cached locally
# 6400 done.
# Downloading 0 files, 6600 cached locally
# 6600 done.
# Downloading 0 files, 6800 cached locally
# 6800 done.
# Downloading 0 files, 7000 cached locally
# 7000 done.
# Downloading 0 files, 7200 cached locally
# 7200 done.
# Downloading 0 files, 7400 cached locally
# 7400 done.
# Downloading 0 files, 7600 cached locally
# 7600 done.
# Downloading 0 files, 7800 cached locally
# 7800 done.
# Downloading 0 files, 8000 cached locally
# 8000 done.
# Downloading 0 files, 8200 cached locally
# 8200 done.
# Downloading 0 files, 8400 cached locally
# 8400 done.
# Downloading 0 files, 8600 cached locally
# 8600 done.
# Downloading 0 files, 8800 cached locally
# 8800 done.
# Downloading 0 files, 9000 cached locally
# 9000 done.
# Downloading 0 files, 9200 cached locally
# 9200 done.
# Downloading 0 files, 9400 cached locally
# 9400 done.
# Downloading 0 files, 9600 cached locally
# 9600 done.
# Downloading 0 files, 9800 cached locally
# 9800 done.
# Downloading 0 files, 10000 cached locally
# 10000 done.
# Downloading 0 files, 10200 cached locally
# 10200 done.
# Downloading 0 files, 10400 cached locally
# 10400 done.
# Downloading 0 files, 10600 cached locally
# 10600 done.
# Downloading 0 files, 10800 cached locally
# 10800 done.
# Downloading 0 files, 11000 cached locally
# 11000 done.
# Downloading 0 files, 11200 cached locally
# 11200 done.
# Downloading 0 files, 11400 cached locally
# 11400 done.
# Downloading 0 files, 11600 cached locally
# 11600 done.
# Downloading 0 files, 11800 cached locally
# 11800 done.
# Downloading 0 files, 12000 cached locally
# 12000 done.
# Downloading 0 files, 12200 cached locally
# 12200 done.
# Downloading 0 files, 12400 cached locally
# 12400 done.
# Downloading 0 files, 12600 cached locally
# 12600 done.
# Downloading 0 files, 12800 cached locally
# 12800 done.
# Downloading 0 files, 13000 cached locally
# 13000 done.
# Downloading 0 files, 13200 cached locally
# 13200 done.
# Downloading 0 files, 13400 cached locally
# 13400 done.
# Downloading 0 files, 13600 cached locally
# 13600 done.
# Downloading 0 files, 13800 cached locally
# 13800 done.
# Downloading 0 files, 14000 cached locally
# 14000 done.
# Downloading 0 files, 14200 cached locally
# 14200 done.
# Downloading 0 files, 14400 cached locally
# 14400 done.
# Downloading 0 files, 14600 cached locally
# 14600 done.
# Downloading 0 files, 14800 cached locally
# 14800 done.
# Downloading 0 files, 15000 cached locally
# 15000 done.
# Downloading 0 files, 15200 cached locally
# 15200 done.
# Downloading 0 files, 15400 cached locally
# 15400 done.
# Downloading 0 files, 15600 cached locally
# 15600 done.
# Downloading 0 files, 15800 cached locally
# 15800 done.
# Downloading 0 files, 16000 cached locally
# 16000 done.
# Downloading 0 files, 16200 cached locally
# 16200 done.
# Downloading 0 files, 16400 cached locally
# 16400 done.
# Downloading 0 files, 16600 cached locally
# 16600 done.
# Downloading 0 files, 16800 cached locally
# 16800 done.
# Downloading 0 files, 17000 cached locally
# 17000 done.
# Downloading 0 files, 17200 cached locally
# 17200 done.
# Downloading 0 files, 17400 cached locally
# 17400 done.
# Downloading 0 files, 17600 cached locally
# 17600 done.
# Downloading 0 files, 17800 cached locally
# 17800 done.
# Downloading 0 files, 18000 cached locally
# 18000 done.
# Downloading 0 files, 18200 cached locally
# 18200 done.
# Downloading 0 files, 18400 cached locally
# 18400 done.
# Downloading 0 files, 18600 cached locally
# 18600 done.
# Downloading 0 files, 18800 cached locally
# 18800 done.
# Downloading 0 files, 19000 cached locally
# 19000 done.
# Downloading 0 files, 19200 cached locally
# 19200 done.
# Downloading 0 files, 19400 cached locally
# 19400 done.
# Downloading 0 files, 19600 cached locally
# 19600 done.
# Downloading 0 files, 19800 cached locally
# 19800 done.
# Downloading 0 files, 20000 cached locally
# 20000 done.
# Downloading 0 files, 20200 cached locally
# 20200 done.
# Downloading 0 files, 20400 cached locally
# 20400 done.
# Downloading 0 files, 20600 cached locally
# 20600 done.
# Downloading 0 files, 20800 cached locally
# 20800 done.
# Downloading 0 files, 21000 cached locally
# 21000 done.
# Downloading 0 files, 21200 cached locally
# 21200 done.
# Downloading 200 files, 21200 cached locally
# 21400 done.
# Downloading 200 files, 21400 cached locally
# 21600 done.
# Downloading 200 files, 21600 cached locally
# 21800 done.
# Downloading 200 files, 21800 cached locally
# 22000 done.
# Downloading 200 files, 22000 cached locally
# 22200 done.
# Downloading 200 files, 22200 cached locally
# 22400 done.
# Downloading 200 files, 22400 cached locally
# 22600 done.
# Downloading 200 files, 22600 cached locally
# 22800 done.
# Downloading 200 files, 22800 cached locally
# 23000 done.
# Downloading 200 files, 23000 cached locally
# 23200 done.
# Downloading 200 files, 23200 cached locally
# 23400 done.
# Downloading 200 files, 23400 cached locally
# 23600 done.
# Downloading 200 files, 23600 cached locally
# 23800 done.
# Downloading 200 files, 23800 cached locally
# 24000 done.
# Downloading 200 files, 24000 cached locally
# 24200 done.
# Downloading 200 files, 24200 cached locally
# 24400 done.
# Downloading 200 files, 24400 cached locally
# 24600 done.
# Downloading 200 files, 24600 cached locally
# 24800 done.
# Downloading 200 files, 24800 cached locally
# 25000 done.
# Downloading 200 files, 25000 cached locally
# 25200 done.
# Downloading 200 files, 25200 cached locally
# 25400 done.
# Downloading 200 files, 25400 cached locally
# 25600 done.
# Downloading 200 files, 25600 cached locally
# 25800 done.
# Downloading 200 files, 25800 cached locally
# 26000 done.
# Downloading 200 files, 26000 cached locally
# 26200 done.
# Downloading 200 files, 26200 cached locally
# 26400 done.
# Downloading 200 files, 26400 cached locally
# 26600 done.
# Downloading 200 files, 26600 cached locally
# 26800 done.
# Downloading 200 files, 26800 cached locally
# 27000 done.
# Downloading 200 files, 27000 cached locally
# 27200 done.
# Downloading 200 files, 27200 cached locally
# 27400 done.
# Downloading 200 files, 27400 cached locally
# 27600 done.
# Downloading 200 files, 27600 cached locally
# 27800 done.
# Downloading 200 files, 27800 cached locally
# 28000 done.
# Downloading 200 files, 28000 cached locally
# 28200 done.
# Downloading 200 files, 28200 cached locally
# 28400 done.
# Downloading 200 files, 28400 cached locally
# 28600 done.
# Downloading 200 files, 28600 cached locally
# 28800 done.
# Downloading 200 files, 28800 cached locally
# 29000 done.
# Downloading 200 files, 29000 cached locally
# 29200 done.
# Downloading 200 files, 29200 cached locally
# 29400 done.
# Downloading 200 files, 29400 cached locally
# 29600 done.
# Downloading 200 files, 29600 cached locally
# 29800 done.
# Downloading 200 files, 29800 cached locally
# 30000 done.
# Downloading 200 files, 30000 cached locally
# 30200 done.
# Downloading 200 files, 30200 cached locally
# 30400 done.
# Downloading 200 files, 30400 cached locally
# 30600 done.
# Downloading 200 files, 30600 cached locally
# 30800 done.
# Downloading 200 files, 30800 cached locally
# 31000 done.
# Downloading 200 files, 31000 cached locally
# 31200 done.
# Downloading 200 files, 31200 cached locally
# 31400 done.
# Downloading 200 files, 31400 cached locally
# 31600 done.
# Downloading 200 files, 31600 cached locally
# 31800 done.
# Downloading 200 files, 31800 cached locally
# 32000 done.
# Downloading 200 files, 32000 cached locally
# 32200 done.
# Downloading 200 files, 32200 cached locally
# 32400 done.
# Downloading 200 files, 32400 cached locally
# 32600 done.
# Downloading 200 files, 32600 cached locally
# 32800 done.
# Downloading 200 files, 32800 cached locally
# 33000 done.
# Downloading 200 files, 33000 cached locally
# 33200 done.
# Downloading 200 files, 33200 cached locally
# 33400 done.
# Downloading 200 files, 33400 cached locally
# 33600 done.
# Downloading 200 files, 33600 cached locally
# 33800 done.
# Downloading 200 files, 33800 cached locally
# 34000 done.
# Downloading 200 files, 34000 cached locally
# 34200 done.
# Downloading 200 files, 34200 cached locally
# 34400 done.
# Downloading 200 files, 34400 cached locally
# 34600 done.
# Downloading 200 files, 34600 cached locally
# 34800 done.
# Downloading 200 files, 34800 cached locally
# 35000 done.
# Downloading 200 files, 35000 cached locally
# 35200 done.
# Downloading 200 files, 35200 cached locally
# 35400 done.
# Downloading 200 files, 35400 cached locally
# 35600 done.
# Downloading 200 files, 35600 cached locally
# 35800 done.
# Downloading 200 files, 35800 cached locally
# 36000 done.
# Downloading 200 files, 36000 cached locally
# 36200 done.
# Downloading 200 files, 36200 cached locally
# 36400 done.
# Downloading 204 files, 36396 cached locally
# 36600 done.
# Downloading 47 files, 36604 cached locally
# 36800 done.
# Downloading 0 files, 36651 cached locally
# 37000 done.
# Downloading 0 files, 36651 cached locally
# 37200 done.
# Downloading 0 files, 36651 cached locally
# 37400 done.
# Downloading 0 files, 36651 cached locally
# 37600 done.
# Downloading 0 files, 36651 cached locally
# 37800 done.
# Downloading 0 files, 36651 cached locally
# 38000 done.
# Downloading 0 files, 36651 cached locally
# 38200 done.
# Downloading 0 files, 36651 cached locally
# 38400 done.
# Downloading 0 files, 36651 cached locally
# 38600 done.
# Downloading 0 files, 36651 cached locally
# 38800 done.
# Downloading 0 files, 36651 cached locally
# 39000 done.
# Downloading 0 files, 36651 cached locally
# 39200 done.
# Downloading 0 files, 36651 cached locally
# 39400 done.
# Downloading 0 files, 36651 cached locally
# 39600 done.
# Downloading 0 files, 36651 cached locally
# 39800 done.
# Downloading 0 files, 36651 cached locally
# 40000 done.

# %%
print(actv_walking)

# %%
####################
# Feature Extraction
####################
## PLACE YOUR FEATURE EXTRACTION CODE HERE ##
## THE FOLLOWING IS AN EXAMPLE CODE PLACEHOLDER ##

# temp example of feature extraction
# get average(mean) x-coordinate UserAcceleration for each file
x_accel = [] # initialize empty list for storing x-acceleration values
avg_items = [] # initialize empty list for storing mean values

# loop through each row in dataframe to read in json file
# grab the userAcceleration x-values and calculate the means
for row in actv_walk_temp["outbound_walk_json_file"]: 
	with open(row) as json_data:
		data = json.load(json_data)
		for item in data:
			x = item.get("userAcceleration").get("x")
			x_accel.append(x)
		avg = np.mean(x_accel)
		avg_items.append(avg)

# create new column in dataframe from list of averaged values
actv_walk_temp["meanXaccel"] = avg_items

# Remove unnecessary columns
actv_walk = actv_walk_temp.drop(["deviceMotion_walking_outbound.json.items", "idx", "outbound_walk_json_file"], axis=1)




#### END FEATURE EXTRACTION SNIPPET EXAMPLE ##

# %%
print(walk_json_files_temp)
